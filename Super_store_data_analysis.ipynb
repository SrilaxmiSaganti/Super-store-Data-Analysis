# %% [markdown]
# <a href="https://colab.research.google.com/github/SrilaxmiSaganti/Super-store-Data-Analysis/blob/main/Super_store_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %matplotlib inline
pd.set_option('display.max_columns', 22)
pd.set_option('display.max_rows', 10)

# %%
df = pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.drop(columns="Postal Code",inplace=True)

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
print(df["Ship Mode"].unique())
print(df["Segment"].unique())
print(df["Country"].unique())
print(df["Category"].unique())
print(df["Sub-Category"].unique())
print(df["Region"].unique())
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# ['Consumer' 'Corporate' 'Home Office']
# ['United States']
# ['Furniture' 'Office Supplies' 'Technology']
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']
# ['South' 'West' 'Central' 'East']

# %%
#stastical description of data:
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.1+ KB

# %%
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
#                ..
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# Length: 12, dtype: int64

# %%
df['Ship Mode'].describe()
# Out:
# count               9994
# unique                 4
# top       Standard Class
# freq                5968
# Name: Ship Mode, dtype: object

# %%
df['State'].describe()
# Out:
# count           9994
# unique            49
# top       California
# freq            2001
# Name: State, dtype: object

# %%
#sales analysis based on region
df.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# From the above graph ,WEST region has good sales

# %%
df.groupby("Region")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# Accordingly,from the bar graph WEST region is more profitable

# %%
df.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Region")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
df.groupby("Segment")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %% [markdown]
# From the above graph,we infer consumer segment has more sales

# %%
df.groupby("Segment")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %% [markdown]
# Accordingly, consumer segment has more profits

# %%
df.groupby("Category")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# From the above graph we infer the category TECHNOLOGY has more number of sales

# %%
df.groupby("Category")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# Accordingly, Profits are also high in TECHNOLOGY Category

# %%
df.groupby("Category")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Category")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
df.groupby("State")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# From the graph ,we can observe the sales are high in the states California,New York and Texas

# %%
df.groupby("State")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# From the above graph,the profits are almost same in California and New York

# %%
df['Segment'].describe()
# Out:
# count         9994
# unique           3
# top       Consumer
# freq          5191
# Name: Segment, dtype: object

# %%
df['Category'].describe()
# Out:
# count                9994
# unique                  3
# top       Office Supplies
# freq                 6026
# Name: Category, dtype: object

# %%
df['Sub-Category'].describe()
# Out:
# count        9994
# unique         17
# top       Binders
# freq         1523
# Name: Sub-Category, dtype: object

# %%
df['Profit'].describe()
# Out:
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64

# %%
df['City'].describe()
# Out:
# count              9994
# unique              531
# top       New York City
# freq                915
# Name: City, dtype: object

# %%
df['Region'].describe()
# Out:
# count     9994
# unique       4
# top       West
# freq      3203
# Name: Region, dtype: object

# %%
df.groupby("State")["Discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# From the above graph ,Discount is more in the state Texas

# %%
df.groupby("Category")["Discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Discount'>

# %% [markdown]
# Pie chart shows the most discounted category is Office Supplies

# %%
df.groupby("Segment")["Discount"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Discount'>

# %% [markdown]
# From the Pie chart we infer that the most discounted segment is consumer segment

# %%
df.groupby("Sub-Category")["Discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='Sub-Category'>

# %% [markdown]
# The discount is high in the Binders sub category

# %%
df.groupby("Quantity")["Discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='Quantity'>

# %% [markdown]
# From the graph ,2 & 3 Quantities of the product can get the maximum discount

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
imp_categotical_features=df[['Ship Mode','Segment', 'City', 'State','Region','Category', 'Sub-Category']]

for col in imp_categotical_features:
    width=8
    n=len(df[col].unique())
    if n > 15:
        width=20
        plt.figure(figsize=(width,4))
        temp=pd.DataFrame(df[col].value_counts().sort_values(ascending=False)[:35],columns=[col])
        sns.barplot(data=temp,x=temp.index,y=col,palette= 'Reds')
        plt.ylabel("count")
        plt.xlabel(col)
        plt.xticks(rotation=60)
    else:
        plt.figure(figsize=(width,4))
        sns.countplot(data=df,x=col,palette='Blues')
    plt.show()

# %%
#count of sub category
sns.countplot(x='Sub-Category', data = df)
sns.set(rc={'figure.figsize':(12,5)})
sns.barplot(data=temp,x=temp.index,y=col,palette= 'Greens')
plt.xticks(rotation=60)
plt.title('Count of SubCategory')
plt.show()

# %% [markdown]
# OBSERVATION FROM GENERAL EXPLORATORY DATA ANALYSIS ABOVE
#
# Majority of the customers prefer the Standard Class Shipment mode.
# Most of the customers are from the Consumer segment.
# Among all the cities New York City records the maximum purchases made followed by Los Angeles.
# Among all the states New California records the maximum purchases made followed New York.
# Majority of the purchases are in the East and West regions as compared to South & Central.
# Office Supplies lead the purchases made Category.
# Binders and Paper are the leaders in Product Sub-Category.

# %% [markdown]
# **Region with highest count**

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Region', data = df)
plt.xticks(rotation = 0)
plt.title('Count Per Region')
plt.show()

# %% [markdown]
# **BEST SELLING AND PROFITABLE CATEGORY**

# %%
df1_sum = pd.DataFrame(df.groupby(['Category'])[['Discount', 'Profit', 'Quantity']].sum())
df1_sum
# Out:
#                  Discount       Profit  Quantity
# Category
# Furniture          368.89   18451.2728      8028
# Office Supplies    947.80  122490.8008     22906
# Technology         244.40  145454.9481      6939

# %%
df1_avg = pd.DataFrame(df.groupby(['Category'])[['Discount', 'Profit', 'Quantity']].mean())
df1_avg
# Out:
#                  Discount     Profit  Quantity
# Category
# Furniture        0.173923   8.699327  3.785007
# Office Supplies  0.157285  20.327050  3.801195
# Technology       0.132323  78.752002  3.756903

# %% [markdown]
# **Most profitable category**

# %%
df2_avg = pd.DataFrame(df.groupby(['Sub-Category'])[['Discount', 'Profit']].mean())

# Sort by descending order according to sales
sub_df2 = pd.DataFrame(df2_avg.sort_values('Discount', ascending = False))
sub_df2 = sub_df2.reset_index()
sub_df2.head(5)
# Out:
#   Sub-Category  Discount     Profit
# 0      Binders  0.372292  19.843574
# 1     Machines  0.306087  29.432669
# 2       Tables  0.261285 -55.565771
# 3    Bookcases  0.211140 -15.230509
# 4       Chairs  0.170178  43.095894
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_1504650093309531803 = autoviz.get_df('df_1504650093309531803')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1504650093309531803, *['index'], **{})
# chart
# import numpy as np
# ...

# %% [markdown]
# **TOP TEN BEST PERFORMING CITIES**

# %%
city_sales_df = pd.DataFrame(df.groupby(['City'])['Discount','Quantity','Profit'].mean().
                             sort_values('Discount',ascending = False))
top10 = city_sales_df[:10]
top10
# Out:
#                Discount  Quantity    Profit
# City
# Missouri City  0.800000       7.0  -9.55500
# Romeoville     0.800000       2.0 -14.77080
# Deer Park      0.800000       6.0 -10.38600
# Abilene        0.800000       2.0  -3.75840
# Elyria         0.700000       1.0  -1.39840
# Littleton      0.700000       1.0 -98.80180
# Ormond Beach   0.700000       3.0  -1.96560
# Pensacola      0.700000       3.0  -1.47600
# Tyler          0.640000       3.2 -88.74172
# Bryan          0.616667       4.5 -35.61860

# %% [markdown]
# **BEST PREFERRED SHIP MODE**

# %%
# Taking a subset of data (To keep things simple)
df_stackb = df[['Ship Mode','Discount','Profit','Sales']]
# taking a groupby on category and then ship mode...
df_stackb = df_stackb.groupby(['Ship Mode']).sum().reset_index()
# df_stackb

# Visualizing the Stacked BarChart
plt.figure(figsize=[10,15])
plt.subplot(3,1,1)
plt.bar(x=df_stackb['Ship Mode'], height=df_stackb['Discount'], color='#F05454')
plt.bar(x=df_stackb['Ship Mode'], height=df_stackb['Profit'], bottom=df_stackb['Discount'], color='#30475E')
plt.title("Sales & Profit Across Ship Modes", size=20, pad=20)
plt.legend(['Sales','Profit'])

# %% [markdown]
# **Loss analysis**

# %%
loss_df = df[df['Profit'] < 0]
loss_with_zero_df = df[(df['Profit'] < 0) ]
loss_with_zero_df.head()
# Out:
#          Ship Mode      Segment        Country             City         State  \
# 3   Standard Class     Consumer  United States  Fort Lauderdale       Florida
# 14  Standard Class  Home Office  United States       Fort Worth         Texas
# 15  Standard Class  Home Office  United States       Fort Worth         Texas
# 23    Second Class     Consumer  United States     Philadelphia  Pennsylvania
# 27  Standard Class     Consumer  United States     Philadelphia  Pennsylvania
#
#     Postal Code   Region         Category Sub-Category      Sales  Quantity  \
# 3         33311    South        Furniture       Tables   957.5775         5
# 14        76106  Central  Office Supplies   Appliances    68.8100         5
# 15        76106  Central  Office Supplies      Binders     2.5440         3
# 23        19140     East        Furniture       Chairs    71.3720         2
# 27        19140     East        Furniture    Bookcases  3083.4300         7
#
#     Discount     Profit
# ...
